# %%
import pandas as pd

# %%
path='/home/ubuntu/fintech80-codes-thu/dataset/data'
df = pd.read_csv(path+'/Selfdriving_IOT_1.csv')
df
# Out:
#             timestamp  forward_acceleration  right_acceleration  \
# 0          537.130659             -0.564484           -0.872314
# 1          537.130731             -0.564484           -0.872314
# 2          537.135269             -0.564484           -0.872314
# 3          537.135269             -0.564484           -0.872314
# 4          537.135269             -0.640656           -0.780589
# ...               ...                   ...                 ...
# 7458880  46228.574951             -0.795209            1.892726
# 7458881  46228.574951             -0.760910            1.875977
# 7458882  46228.574951             -0.760910            1.875977
# 7458883  46228.574951             -0.760910            1.875977
# 7458884  46228.578270             -0.760910            1.875977
#
#          down_acceleration  forward_gyro_uncalibrated  \
# 0                -9.570679                  -0.021988
# 1                -9.570679                  -0.021988
# ...
